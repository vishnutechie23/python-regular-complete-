# %%
def p(a):
    print(f"inner value = {a} ")

a = 10 
print(f"outer value = {a}")
p(a)

# %%
def p(a):
    print(f"inner value = {a}")

a = 10
print(f"outer value = {a}")
p(a)
# Out:
# outer value = 10
# inner value = 10

# %%
def p(a):
    a = 20
    print(f"inner value = {a}")

a = 10
print(f"outer value = {a}")
p(a)
# Out:
# outer value = 10
# inner value = 20
