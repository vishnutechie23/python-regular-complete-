# %% [markdown]
# # Dictionary

# %% [markdown]
# ## Initialization

# %%
d1 = {} 
d2 = dict() 
d3 = {1 : 2, 3 : 4}
d4 = dict({5 : 6, 7 : 8})
# d5 = dict('a' = 10, 'b' = 20)
d5 = dict([(10, 20), (30, 40), (50, 60)])

print(f"Dictionary 1 : {d1}\nMemory Location : {id(d1)}\nData Type : {type(d1)}\n")
print(f"Dictionary 2 : {d2}\nMemory Location : {id(d2)}\nData Type : {type(d2)}\n")
print(f"Dictionary 3 : {d3}\nMemory Location : {id(d3)}\nData Type : {type(d3)}\n")
print(f"Dictionary 4 : {d4}\nMemory Location : {id(d4)}\nData Type : {type(d4)}\n")
print(f"Dictionary 5 : {d5}\nMemory Location : {id(d5)}\nData Type : {type(d5)}\n")
# Out:
# Dictionary 1 : {}
# Memory Location : 2307185413760
# Data Type : <class 'dict'>
#
# Dictionary 2 : {}
# Memory Location : 2307185413248
# Data Type : <class 'dict'>
#
# Dictionary 3 : {1: 2, 3: 4}
# Memory Location : 2307179116800
# Data Type : <class 'dict'>
#
# Dictionary 4 : {5: 6, 7: 8}
# Memory Location : 2307185412736
# Data Type : <class 'dict'>
#
# Dictionary 5 : {10: 20, 30: 40, 50: 60}
# Memory Location : 2307185410560
# Data Type : <class 'dict'>

# %%
king = {
    "Name" : "Virat Kohli", 
    "Jersey No" : 18, 
    "Best Score" : 254, 
    "Best Performance" : ['Mohali', 'Melbourne'], 
    "Man Of The Series" : 32, 
    "No Of Centuries" : 85
}

# %%
print(king, type(king))
# Out:
# {'Name': 'Virat Kohli', 'Jersey No': 18, 'Best Score': 254, 'Best Performance': ['Mohali', 'Melbourne'], 'Man Of The Series': 32, 'No Of Centuries': 85} <class 'dict'>

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 85}

# %%
# Accessing 

king['Name']
king['No Of Centuries']
# Out:
# 85

# %%
# king['Wife']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 king['Wife']
#
# KeyError: 'Wife'

# %%
# Get method 

king.get("Man Of The Match", "Key Not Found")
# Out:
# 'Key Not Found'

# %%
# Updation 

king['No Of Centuries'] = 100

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 100}

# %%
# Insertion

# %%
king['Wife'] = "Anuskha Sharma"

# %%
king['Nick Name'] = 'Chiku'

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 100,
#  'Wife': 'Anuskha Sharma',
#  'Nick Name': 'Chiku'}

# %%
# Deletion 

king.pop("Nick Name")
# Out:
# 'Chiku'

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 100,
#  'Wife': 'Anuskha Sharma'}

# %%
king.popitem()
# Out:
# ('Wife', 'Anuskha Sharma')

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 100}

# %%
king.popitem()
# Out:
# ('No Of Centuries', 100)

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man Of The Series': 32,
#  'No Of Centuries': 85}

# %%
# keys 

king.keys()
# Out:
# dict_keys(['Name', 'Jersey No', 'Best Score', 'Best Performance', 'Man Of The Series', 'No Of Centuries'])

# %%
for all_keys in king.keys():
    print(all_keys)
# Out:
# Name
# Jersey No
# Best Score
# Best Performance
# Man Of The Series
# No Of Centuries

# %%
king.values()
# Out:
# dict_values(['Virat Kohli', 18, 254, ['Mohali', 'Melbourne'], 32, 85])

# %%
for value in king.values():
    print(value)
# Out:
# Virat Kohli
# 18
# 254
# ['Mohali', 'Melbourne']
# 32
# 85

# %%
king.items()
# Out:
# dict_items([('Name', 'Virat Kohli'), ('Jersey No', 18), ('Best Score', 254), ('Best Performance', ['Mohali', 'Melbourne']), ('Man Of The Series', 32), ('No Of Centuries', 85)])

# %%
a = (1, 2) 

print(a, type(a))
# Out:
# (1, 2) <class 'tuple'>

# %%
x, y = a

# %%
print(a,x, y)
# Out:
# (1, 2) 1 2

# %%
king.items()
# Out:
# dict_items([('Name', 'Virat Kohli'), ('Jersey No', 18), ('Best Score', 254), ('Best Performance', ['Mohali', 'Melbourne']), ('Man Of The Series', 32), ('No Of Centuries', 85)])

# %%
for item in king.items():
    key, value = item  
    print(f"Key = {key}, value = {value}")
# Out:
# Key = Name, value = Virat Kohli
# Key = Jersey No, value = 18
# Key = Best Score, value = 254
# Key = Best Performance, value = ['Mohali', 'Melbourne']
# Key = Man Of The Series, value = 32
# Key = No Of Centuries, value = 85

# %%
for key, value in king.items(): 
    print(f"Key = {key}, Value = {value}")
# Out:
# Key = Name, Value = Virat Kohli
# Key = Jersey No, Value = 18
# Key = Best Score, Value = 254
# Key = Best Performance, Value = ['Mohali', 'Melbourne']
# Key = Man Of The Series, Value = 32
# Key = No Of Centuries, Value = 85

# %%
squares_dict = {i : i ** 2 for i in range(1, 11, 1)}

# %%
print(squares_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
even_squares = {i : i ** 2 for i in range(1, 11, 1) if i % 2 == 0}
print(even_squares)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
squares_structrue = [(i, i**2) for i in range(1,11,1) if i % 2 == 0]

# %%
squares_structrue
# Out:
# [(2, 4), (4, 16), (6, 36), (8, 64), (10, 100)]

# %%
a, b = 10, 20 

print(a, b)
# Out:
# 10 20

# %%
c = 10, 20 
print(c, type(c))
# Out:
# (10, 20) <class 'tuple'>

# %%
# Membership 

d = {
    'a' : 1, 
    'b' : 2
}

# %%
# By Default -->  Searching in Key 

'a' in d
# Out:
# True

# %%
1 in d
# Out:
# False

# %%
'a' in d.keys()
# Out:
# True

# %%
'a' in d.values( )
# Out:
# False

# %%
1 in d
# Out:
# False

# %%
1 in d.values()
# Out:
# True

# %%
1  in d.keys()
# Out:
# False

# %%
d = {
    'd1' : {'a' : 1, 'b' : 2}, 
    'd2' : {'c' : 3, 'd' : 4}
}

# %%
d
# Out:
# {'d1': {'a': 1, 'b': 2}, 'd2': {'c': 3, 'd': 4}}

# %%
d.get('d2', "Item Not Found").get("df", "Item Not Found")
# Out:
# 'Item Not Found'

# %%
keys = ['a', 'b', 'c']

dictionary = dict.fromkeys(keys, 0) 

print(dictionary)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
dictionary['a'] = "alksjfl;asjdf"

# %%
dictionary
# Out:
# {'a': 'alksjfl;asjdf', 'b': 0, 'c': 0}

# %%
dictionary.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d1 = {
    'a' : 1, 
    'b' : 2
}

d2 = {
    'c' : 3, 
    'd' : 4
}

# %%
d1.update(d2)

# %%
d2
# Out:
# {'c': 3, 'd': 4}

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
d1 = {
    'a' : 1, 
    'b' : 2
}

d2 = {
    'b' : 3, 
    'c' : 4
}

# %%
d1.update(d2)

# %%
d2
# Out:
# {'b': 3, 'c': 4}

# %%
d1
# Out:
# {'a': 1, 'b': 3, 'c': 4}
