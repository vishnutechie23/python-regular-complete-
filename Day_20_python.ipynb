# %%
for i in range(5):
    for k in range(n-i):
        print(" ",end=" ")
    for j in range(i+1):
        print("8",end=" ")
          
    print()
# Out:
#           8
#         8 8
#       8 8 8
#     8 8 8 8
#   8 8 8 8 8

# %%
n = 5 
for i in range(n):
    for j in range(n):
        print("*",end= " ")
        
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *
