# %% [markdown]
# ## local,global in function

# %%
a = 10 
def a = 20: :
    
    return
        print("{a}")

# %%
a = 10 
def add(a):
    print(f"{a}")
a = 20 
add(12)
print(f"{a}")
# Out:
# 12
# 20

# %%
a = 10 
def add():
    print(f"{a}")

a = 20
add() 
print(f"{a}")
# Out:
# 20
# 20
