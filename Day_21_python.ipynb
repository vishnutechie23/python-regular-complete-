# %%
print("1")
# Out:
# 1

# %%
def (a:int, b:int) -> int :
    return a + b
# Out:
#   Cell In[1], line 1
#     def (a:int, b:int) -> int :
#         ^
# SyntaxError: invalid syntax

# %%
for i in range(1,6,1):
    print(i,end=" ") 
print()
n = 5 
for i in range(n):
    for j in range(n):
        print("*",end=" ")
    print()
# Out:
# 1 2 3 4 5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
st = 1
while st < 5 :
    print("*",end=" ")
    st += 1 

    sp = 1
    while sp < 10:
        print("*",end=" ")
        sp +=1
        while st < 5 :
            print("*",end=" ")    
            st += 1
# Out:
# * * * * * * * * * * * * *
