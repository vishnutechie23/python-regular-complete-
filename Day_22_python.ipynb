# %% [markdown]
# ## list mutable

# %% [markdown]
# ## Insertion

# %% [markdown]
# ####  Inserting at the last position of list

# %%
li = [2,5,7,3,9,1,19]
print(li)
# Out:
# [2, 5, 7, 3, 9, 1, 19]

# %%
# obj.method( )
# obj.attribute

# %%
print(li)
# Out:
# [2, 5, 7, 3, 9, 1, 19]

# %%
li.append(200)
print(li)
# Out:
# [2, 5, 7, 3, 9, 1, 19, 200]

# %%
li.insert(0, 3892) 
print(li)
# Out:
# [3892, 2, 5, 7, 3, 9, 1, 19, 200]

# %%
li.insert(5, 1010)
print(li)
# Out:
# [3892, 2, 5, 7, 3, 1010, 9, 1, 19, 200]

# %%
li.append(22)
print(li)
# Out:
# [3892, 2, 5, 7, 3, 1010, 9, 1, 19, 200, 22]

# %%
li.insert(9,212)
print(li)
# Out:
# [3892, 2, 5, 7, 3, 1010, 9, 1, 19, 212, 200, 22]
